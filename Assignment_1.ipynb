# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will      be mathematical operators.
# -------------------------------------------------------------------------------------------------------------------------------
# *
# 'hello'
# -87.8
# -
# /
# +
# -------------------------------------------------------------------------------------------------------------------------------
# Sol :
#
# *      - Mathematical operator
# 'hello'- Values
# -87.8  - Values
# -      - Mathematical operator
# /      - Mathematical operator
# +      - Mathematical operator
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 2. What is the difference between string and variable?
# -------------------------------------------------------------------------------------------------------------------------------
# Sol :
#
# String: A string is a sequence of characters used to represent text in Python.
# Example: "Hello, World!" is a string.
#
# Variable: A variable is a name that holds a value which can be any data type, like a string, integer, list, etc.
# Example: my_variable = "Hello, World!" where my_variable is a variable storing a string.
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 3. Describe three different data types.
# -------------------------------------------------------------------------------------------------------------------------------
# Sol :
#
# (a)Integer : An integer is a whole number, without a fractional component. It can be positive, negative, or zero.
#    Example: 42, -7, 0
#    Usage: Used for counting, indexing, and arithmetic operations where whole numbers are required.
#    Operations: Addition (+), subtraction (-), multiplication (*), division (/), modulus (%), etc.
#
# (b)Float : A float is a number that has a decimal point. It represents real numbers and is used for precise calculations.
#    Example: 3.14, -0.001, 2.0
#    Usage: Used in calculations that require precision, such as scientific computations, measurements, and financial                calculations.
#    Operations: Similar to integers, with additional operations for dealing with decimals.
#
# (c)List : A list is an ordered collection of items (elements) which can be of different data types. Lists are mutable, meaning    they can be changed after creation.
#    Example: [1, 2, 3], ['apple', 'banana', 'cherry']
#    Usage: Used to store sequences of data, such as a collection of items, results of computations, or multiple values of the      same type.
#    Operations: Indexing, slicing, appending (append()), inserting (insert()), removing (remove()), etc.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 4. What is an expression made up of? What do all expressions do?
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# An expression in Python is made up of a combination of:
#
# (a)Operands: Values that are manipulated by operators. Operands can be:
#
# * Literals           : Direct values like numbers (42, 3.14), strings ("hello"), etc.
# *Variables           : Names that store values (x, my_var).
# *Function calls      : Invocations of functions that return values (len(my_list)).
# *Complex expressions : Combinations of the above (x + y, 2 * (a + b)).
#
# (b)Operators: Symbols that perform operations on operands. Common operators include:
#
# *Arithmetic operators : + (addition), - (subtraction), * (multiplication), / (division), % (modulus).
# *Comparison operators : == (equal), != (not equal), < (less than), > (greater than), <= (less than or equal to), >= (greater                           than or equal to).
# *Logical operators    : and, or, not.
# *Assignment operators : =, +=, -=, *=, /=, etc.
# *Bitwise operators    : & (AND), | (OR), ^ (XOR), ~ (NOT), << (left shift), >> (right shift).
#
# What Do All Expressions Do?
# All expressions evaluate to a value. This means that when an expression is executed, it produces a result. The result can be of any data type, such as an integer, float, string, list, boolean, etc.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 5.This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# Expression : An expression is a combination of values, variables, operators, and function calls that is evaluated to produce a single value.
# Example    : 2 + 3 evaluates to 5.
# Purpose    : To compute and return a value.
#
# Statement: A statement is an instruction that the Python interpreter can execute. Statements perform actions.
# Example  : spam = 10 assigns the value 10 to the variable spam.
# Purpose  : To execute an action, such as assigning a value, printing, or controlling flow.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 6. After running the following code, what does the variable bacon contain?
#    bacon = 22
#    bacon + 1
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# After running the following code:
#
# bacon = 22
# bacon + 1
#
# "The variable bacon still contains the value 22."
#
# Explanation:
#
# *As bacon = 22 is an assignment Statement.
# *This assigns the value 22 to the variable bacon.
#
# While bacon + 1 is an expression.This evaluates the expression bacon + 1, which results in 23, but this value is not assigned to any variable. The original value of bacon remains unchanged because no assignment was made.
#
# So, the value of bacon after this code is still 22.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 7. What should the values of the following two terms be?
#    'spam' + 'spamspam'
#    'spam' * 3
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# The values of the following two terms should be:
#
# Expression: 'spam' + 'spamspam'
#
# Result      : 'spamspamspam'
# Explanation : The + operator concatenates (joins) the two strings 'spam' and 'spamspam', resulting in 'spamspamspam'.
#
# Expression  : 'spam' * 3
# Result      : 'spamspamspam'
# Explanation : The * operator repeats the string 'spam' three times, resulting in 'spamspamspam'.
#
# Both expressions produce the same result: 'spamspamspam'.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 8. Why is eggs a valid variable name while 100 is invalid?
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# Rules for Valid Variable Names in Python
#     ->Must start with a letter (a-z, A-Z) or an underscore (_).
#     ->Can contain letters, digits (0-9), and underscores (_) after the first character.
#     ->Cannot be a reserved keyword in Python (like if, else, for, etc.).
#
# -> Valid Variable Name: eggs
#
#    Reason: It starts with a letter and follows the rules for variable naming in Python.
#
# -> Invalid Variable Name: 100
#
#    Reason: Variable names cannot start with a number.
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# -------------------------------------------------------------------------------------------------------------------------------
# Sol:
#
# The three functions in Python that can be used to convert a value to an integer, floating-point number, or string are:
#
#     int(): Converts a value to an integer.
#     float(): Converts a value to a floating-point number.
#     str(): Converts a value to a string.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# -------------------------------------------------------------------------------------------------------------------------------
# 10.Why does this expression cause an error? How can you fix it?
#    'I have eaten ' + 99 + ' burritos.'
# -------------------------------------------------------------------------------------------------------------------------------
# Sol :
#
# The expression causes an error because we are trying to concatenate a string with an integer, which is not allowed in Python. In Python, we can only concatenate strings with other strings.
#
# Fixing the Expression:
#
# To fix the expression, you need to convert the integer 99 to a string using the str() function before concatenating it with other strings.
#
# Corrected Expression : 'I have eaten ' + str(99) + ' burritos.'
#
# Explanation :
#
# * Convert the Integer to String: str(99) converts the integer 99 to the string "99".
# * Concatenate the Strings: Now, you are concatenating three strings: 'I have eaten ', '99', and ' burritos.'.
#
# Result:
# The corrected expression will correctly concatenate the strings and produce the following output: 'I have eaten 99 burritos.'
#
# -------------------------------------------------------------------------------------------------------------------------------
